# %% [markdown]
# Akil Bhuiyan <br>
# Professor Matthew Fried <br>
# CSCI 381 (Data Analytics) <br>
# Final Project
#
# [FinalProject.ppt](https://drive.google.com/open?id=11WAF92WH3-t7pMwEYUFTcuHOpBiVQN9E)

# %% [markdown]
# # Building a Machine Learning Algorithm to predict the HIV impact on certain ethnicity or areas
#
#
#
# # Introduction
#
# Some facts about HIV in the USA are HIV/AIDS is a big problem in our country and HIV is not the same as AIDS, HIV tests are reliable and HIV can not be cured. It is very unfortunate that about 13% of people living with HIV in the US do not know they are infected. AIDS is the most serious stage of HIV, and it leads to death over time. Without treatment, it usually takes about 10 years for someone with HIV to develop AIDS. Treatment slows down the damage the virus causes and can help people stay healthy for several decades. Using ML algorithms, our goal is to analyze our data and predict the output values within an acceptable range.
#
#
#
# # Research Question and Data:
# How does HIV impact on certain ethnicity or areas?
#
# Our Data Set represents HIV/AIDS Diagnoses by Neighborhood, Sex, and Race/Ethnicity. This dataset includes data on new diagnoses of HIV and AIDS in NYC for the calendar years 2010 through 2013. Reported cases and case rates (per 100,000 population) are stratified by age group, race/ethnicity, and United Hospital Fund (UHF) neighborhood. The study in our dataset was conducted on both males and females and returns the total number of diagnoses and shows the impact based on the location and the ethnicity.  Rates marked "NA" cannot be calculated because the underlying population size is unknown.
# Tables or charts may contain suppressed data: cells representing 1-5 person(s) with an underlying denominator of < 500 persons, or non-zero cells with a denominator <= 100 as per Intercensal 2014 estimates, are marked with an asterisk (*). In our dataset, we have 2928 rows and 10 attributes with integer, float, and object datatypes.
#
#
# | Attributes Name | Description |
# | --- | ----------- |
# |1- YEAR| Calendar year of report (2010 - 2013)|
# |2- Neighborhood (U.H.F)| United Hospital Fund neighborhood of residence |
# |3- SEX| Male or Female|
# |4- RACE/ETHNICITY| Race or Ethnicity|
# |5- TOTAL NUMBER OF HIV DIAGNOSES|TOTAL NUMBER OF HIV DIAGNOSES|
# |6- HIV DIAGNOSES PER 100,000 POPULATION|HIV DIAGNOSES PER 100,000 POPULATION|
# |7- TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES|TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES|
# |8- PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES|PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES|
# |9- TOTAL NUMBER OF AIDS DIAGNOSES|TOTAL NUMBER OF AIDS DIAGNOSES|
# |10- AIDS DIAGNOSES PER 100,000 POPULATION|AIDS DIAGNOSES PER 100,000 POPULATION|
#
#
#
# # Data To be Used:
# > For our final project I used [NYC OpenData](https://data.cityofnewyork.us/Health/HIV-AIDS-Diagnoses-by-Neighborhood-Sex-and-Race-Et/ykvb-493p) , where I have around 3000 rows with 10 attributes.
#
#
#
# # Approach:
# The data will be managed by reading into the GitHub raw data link and performing necessary data preparation, cleaning, and scaling operations. We plan to do an entire EDA that includes searching for relationships among variables, testing for multicollinearity, and independence, showing charts, regressions, models, and much more.

# %% [markdown]
# # Hypothesis:
#
# Based on the background research in regard of gender , we learned that community with more LGBT  have high HIV cases. our hypothesis is that the neighborhood with more  LGBT , majority black and Hispanic populations would have highest cases of HIV and AID cases.

# %% [markdown]
# # Data Summary
#
# Some facts about HIV in the USA are HIV/AIDS is a big problem in our country and HIV is not the same as AIDS, HIV tests are reliable and HIV can not be cured. It is very unfortunate that about 13% of people living with HIV in the US do not know they are infected. AIDS is the most serious stage of HIV, and it leads to death over time. Without treatment, it usually takes about 10 years for someone with HIV to develop AIDS. Treatment slows down the damage the virus causes and can help people stay healthy for several decades.
#
#
# > For the project we used [NYC OpenData](https://data.cityofnewyork.us/Health/HIV-AIDS-Diagnoses-by-Neighborhood-Sex-and-Race-Et/ykvb-493p) where we have around 3000 rows with 10 attributes.
#
# ### Data Sets:
#
# Our Data Set represents HIV/AIDS Diagnoses by Neighborhood, Sex, and Race/Ethnicity. This dataset includes data on new diagnoses of HIV and AIDS in NYC for the calendar years 2010 through 2013. Reported cases and case rates (per 100,000 population) are stratified by age group, race/ethnicity, and United Hospital Fund (UHF) neighborhood. The study in our dataset was conducted on both males and females and returns the total number of diagnoses and shows the impact based on the location and the ethnicity.  Rates marked "NA" cannot be calculated because the underlying population size is unknown.
# Tables or charts may contain suppressed data: cells representing 1-5 person(s) with an underlying denominator of < 500 persons, or non-zero cells with a denominator <= 100 as per Intercensal 2014 estimates, are marked with an asterisk (*). In our dataset, we have 2928 rows and 10 attributes with integer, float, and object datatypes.
#
#
# ### Attributes:
#
# | Attributes Name | Description |
# | --- | ----------- |
# |1- YEAR| Calendar year of report (2010 - 2013)|
# |2- Neighborhood (U.H.F)| United Hospital Fund neighborhood of residence |
# |3- SEX| Male or Female|
# |4- RACE/ETHNICITY| Race or Ethnicity|
# |5- TOTAL NUMBER OF HIV DIAGNOSES|TOTAL NUMBER OF HIV DIAGNOSES|
# |6- HIV DIAGNOSES PER 100,000 POPULATION|HIV DIAGNOSES PER 100,000 POPULATION|
# |7- TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES|TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES|
# |8- PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES|PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES|
# |9- TOTAL NUMBER OF AIDS DIAGNOSES|TOTAL NUMBER OF AIDS DIAGNOSES|
# |10- AIDS DIAGNOSES PER 100,000 POPULATION|AIDS DIAGNOSES PER 100,000 POPULATION|

# %% [markdown]
# ## Initial Exploratory Data Analysis
# First, read the data into python using pandas, read csv file.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Original DataSet
csvv = 'https://raw.githubusercontent.com/iakil/CSCI381_DataAnalytics/main/Data/HIV_AIDS.csv'
# we used excel trick and fixit
#csvv = 'https://raw.githubusercontent.com/iakil/CSCI381_DataAnalytics/main/Data/HIV_AIDS_Modified.csv'

dataframe=pd.read_csv(csvv)

#create a second stored value of original data as a safety
df_orignal = dataframe

# updating some of the attribute name to a better one 
dataframe.rename(columns={'YEAR' : 'Year', 'Neighborhood (U.H.F)': 'NEIGHBORHOOD', 'TOTAL NUMBER OF HIV DIAGNOSES': 'NUM_HIV_Digno' , 
                          'HIV DIAGNOSES PER 100,000 POPULATION' : 'HIV_per_population', 
                          'TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES' : 'Num_HIV/AIDs_Digno',
                          'PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES' : 'HIV/AIDS_Among_HIV',
                          'TOTAL NUMBER OF AIDS DIAGNOSES': 'Num_AIDS_Digno',
                          'AIDS DIAGNOSES PER 100,000 POPULATION' : 'AIDS_per_population'},inplace=True)     

dataframe
# Out:
#       Year                        NEIGHBORHOOD     SEX   RACE/ETHNICITY  \
# 0     2010                          Greenpoint    Male            Black
# 1     2011              Stapleton - St. George  Female  Native American
# 2     2010                    Southeast Queens    Male              All
# 3     2012                      Upper Westside  Female          Unknown
# 4     2013                         Willowbrook    Male          Unknown
# ...    ...                                 ...     ...              ...
# 2923  2013                         Sunset Park    Male         Hispanic
# 2924  2013            High Bridge - Morrisania  Female      Multiracial
# 2925  2010  Bedford Stuyvesant - Crown Heights    Male  Native American
# 2926  2011          Long Island City - Astoria    Male            Black
# 2927  2011             Bensonhurst - Bay Ridge  Female         Hispanic
#
#      NUM_HIV_Digno HIV_per_population Num_HIV/AIDs_Digno HIV/AIDS_Among_HIV  \
# ...

# %% [markdown]
# There has 2928 rows and 10 attributes.

# %%
dataframe.describe().T
# Out:
#        count    mean       std     min      25%     50%      75%     max
# Year  2928.0  2011.5  1.118225  2010.0  2010.75  2011.5  2012.25  2013.0

# %% [markdown]
# ## Check the data types, unique values, missing values, count, zero values, and * values.

# %%
#Identify the Data Types
df_info = pd.DataFrame(dataframe.dtypes,columns=['Dtype'])

#Identify the unique values
df_info['Nunique'] = dataframe.nunique()

#check missing values for each column
df_info['MissingValues']=dataframe.isnull().sum()

# Identify the count for each variable
df_info['Count']=dataframe.count()

# Identify the zero values for each variable
df_info['ZeroValues']=(dataframe==0).sum()

# how many '*' values
df_info['*Values']=(dataframe=='*').sum()

#how many unknown values
df_info['Unknown']=(dataframe=='Unknown').sum()

##how many All values
df_info['All']=(dataframe=='All').sum()

df_info
# Out:
#                       Dtype  Nunique  MissingValues  Count  ZeroValues  \
# Year                  int64        4              0   2928           0
# NEIGHBORHOOD         object       44              0   2928           0
# SEX                  object        3              0   2928           0
# RACE/ETHNICITY       object        8              0   2928           0
# NUM_HIV_Digno        object      160              0   2928           0
# HIV_per_population   object      840             68   2860           0
# Num_HIV/AIDs_Digno   object       50              0   2928           0
# HIV/AIDS_Among_HIV   object      233             68   2860           0
# Num_AIDS_Digno       object      127              0   2928           0
# AIDS_per_population  object      686             68   2860           0
#
#                      *Values  Unknown  All
# Year                       0        0    0
# NEIGHBORHOOD               0       68    4
# SEX                        0        0  176
# ...

# %% [markdown]
# Findings:
# >1. There has missing values in HIV_per_population, HIV/AIDS_Among_HIV, and AIDS_per_population.
# 2. There has zero values in Num_HIV/AIDs_Digno and HIV/AIDS_Among_HIV
# 3. There has * values in NUM_HIV_Digno, HIV_per_population, Num_HIV/AIDs_Digno,  and AIDS_per_population.
# 4. There has unknow values in RACE/ETHNICITY. But it does not make sense, so we will drop it later.
# 5. There has All values in NEIGHBORHOOD, SEX, RACE/ETHNICITY. But It does not make sense, so we will drop it later.

# %%
sns.heatmap(dataframe.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Change object Dtype to float Dtype.

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 2928 non-null   int64
#  1   NEIGHBORHOOD         2928 non-null   object
#  2   SEX                  2928 non-null   object
#  3   RACE/ETHNICITY       2928 non-null   object
#  4   NUM_HIV_Digno        2928 non-null   object
#  5   HIV_per_population   2860 non-null   object
#  6   Num_HIV/AIDs_Digno   2928 non-null   object
#  7   HIV/AIDS_Among_HIV   2860 non-null   object
#  8   Num_AIDS_Digno       2928 non-null   object
#  9   AIDS_per_population  2860 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 228.9+ KB

# %%
dataframe=dataframe.dropna()
dataframe.replace('*',0,inplace=True)

dataframe['NUM_HIV_Digno'] = dataframe['NUM_HIV_Digno'].astype(float, errors = 'raise')
dataframe['HIV_per_population'] = dataframe['HIV_per_population'].astype(float, errors = 'raise')
dataframe['Num_HIV/AIDs_Digno'] = dataframe['Num_HIV/AIDs_Digno'].astype(float, errors = 'raise')
dataframe['Num_AIDS_Digno'] = dataframe['Num_AIDS_Digno'].astype(float, errors = 'raise')
dataframe['AIDS_per_population'] = dataframe['AIDS_per_population'].astype(float, errors = 'raise')
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2860 entries, 0 to 2927
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 2860 non-null   int64
#  1   NEIGHBORHOOD         2860 non-null   object
#  2   SEX                  2860 non-null   object
#  3   RACE/ETHNICITY       2860 non-null   object
#  4   NUM_HIV_Digno        2860 non-null   float64
#  5   HIV_per_population   2860 non-null   float64
#  6   Num_HIV/AIDs_Digno   2860 non-null   float64
#  7   HIV/AIDS_Among_HIV   2860 non-null   object
#  8   Num_AIDS_Digno       2860 non-null   float64
#  9   AIDS_per_population  2860 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 245.8+ KB
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/3002263346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# Drop it some unnecessary datas.

# %%
dr = dataframe[dataframe["SEX"]=='All'].index
dataframe.drop(dr,inplace=True)
# Out:
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/3191881652.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop(dr,inplace=True)

# %%
dr1 = dataframe[dataframe["RACE/ETHNICITY"]=='All'].index
dataframe.drop(dr1,inplace=True)
# Out:
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/3143290879.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop(dr1,inplace=True)

# %%
dr2 = dataframe[dataframe["NEIGHBORHOOD"]=='All'].index
dataframe.drop(dr2,inplace=True)
# Out:
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/997322174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop(dr2,inplace=True)

# %%
dr2 = dataframe[dataframe["NEIGHBORHOOD"]=='Unknown'].index
dataframe.drop(dr2,inplace=True)
# Out:
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/3851737993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop(dr2,inplace=True)

# %%
dr2 = dataframe[dataframe["RACE/ETHNICITY"]=='Unknown'].index
dataframe.drop(dr2,inplace=True)
# Out:
# /var/folders/l4/3jrpbdxs1d3d0d9grx88k7s00000gn/T/ipykernel_43802/3837310989.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop(dr2,inplace=True)

# %% [markdown]
# ## Check there has missing data

# %%
# create the bar charts to show percents of nonmissing databy missingo function
import missingno as msno 

msno.bar(dataframe)
plt.title(' Percents of non-missing data ',fontsize=20)
# Out:
# Text(0.5, 1.0, ' Percents of non-missing data ')

# %%
sns.heatmap(dataframe.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dataframe.hist(figsize=(15,20))

plt.gcf().set_size_inches(15, 15)
plt.show()

# %%
d2=dataframe['Num_HIV/AIDs_Digno'].value_counts()
pd.DataFrame(d2)
# Out:
#       Num_HIV/AIDs_Digno
# 0.0                 1377
# 1.0                  255
# 2.0                  113
# 3.0                   68
# 4.0                   52
# 5.0                   30
# 6.0                   27
# 7.0                   21
# 8.0                   20
# 9.0                    9
# 10.0                   9
# 12.0                   6
# 16.0                   5
# 13.0                   4
# 11.0                   4
# 29.0                   3
# 22.0                   2
# 19.0                   2
# 15.0                   2
# 14.0                   2
# 17.0                   1
# 20.0                   1
# 21.0                   1
# 25.0                   1
# 18.0                   1

# %%
a=dataframe['AIDS_per_population']
a=pd.DataFrame(a)
a_copy=a.where(a['AIDS_per_population']!=0)
a_copy.dropna()
# Out:
#       AIDS_per_population
# 0                   275.3
# 5                    34.5
# 16                    7.9
# 17                  200.7
# 30                   13.3
# ...                   ...
# 2919                  2.9
# 2920                 64.3
# 2921                  3.1
# 2923                 19.8
# 2926                 48.8
#
# [900 rows x 1 columns]

# %%
d3=dataframe['SEX'].value_counts()
d3=pd.DataFrame(d3)
d3
# Out:
#          SEX
# Male    1008
# Female  1008

# %%
sns.countplot(x = "SEX" , data = dataframe)
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='count'>

# %%
d4=dataframe['NEIGHBORHOOD'].value_counts()
d4=pd.DataFrame(d4)
d4
# Out:
#                                       NEIGHBORHOOD
# Greenpoint                                      48
# Washington Heights - Inwood                     48
# High Bridge - Morrisania                        48
# Bensonhurst - Bay Ridge                         48
# Upper Westside                                  48
# Southeast Queens                                48
# Upper Eastside                                  48
# Kingsbridge - Riverdale                         48
# East New York                                   48
# Northeast Bronx                                 48
# Greenwich Village - SoHo                        48
# Stapleton - St. George                          48
# Canarsie - Flatlands                            48
# Hunts Point - Mott Haven                        48
# Lower Manhattan                                 48
# Williamsburg - Bushwick                         48
# East Harlem                                     48
# ...

# %%
d5=dataframe['RACE/ETHNICITY'].value_counts()
d5=pd.DataFrame(d5)
d5
# Out:
#                         RACE/ETHNICITY
# Black                              336
# Native American                    336
# Multiracial                        336
# Asian/Pacific Islander             336
# White                              336
# Hispanic                           336

# %%
RE_dictionary={"Black":336,"Native American": 336,  "Multiracial" : 336, "Asian/Pacific Islander" : 336, "White" : 336, "Hispanic" : 336, }
RE_Frame=pd.DataFrame(pd.DataFrame(RE_dictionary.items(), columns=['RACE/ETHNICITY', 'Value']))
plt.figure(figsize=(9,5))
sns.barplot(x=RE_Frame['RACE/ETHNICITY'],y=RE_Frame['Value'],data=RE_Frame)
# Out:
# <AxesSubplot:xlabel='RACE/ETHNICITY', ylabel='Value'>

# %% [markdown]
# There has all equal number of race.

# %% [markdown]
# #Boxplot

# %%
values=dataframe[['NUM_HIV_Digno' , 'HIV_per_population' , 'Num_HIV/AIDs_Digno' , 'Num_AIDS_Digno' ,'AIDS_per_population']]
sns.catplot(data=values,kind='box',height=5,aspect=2)
plt.gcf().set_size_inches(10, 8)

# %%
num_columns = []
ca_columns = []

for x in dataframe.columns[:]:
    if(dataframe[x].dtype=='object'):
        ca_columns.append(x)
    else:
        num_columns.append(x)
        
print('Numerical variables:',num_columns)
print('Categorical variables:',ca_columns)
# Out:
# Numerical variables: ['Year', 'NUM_HIV_Digno', 'HIV_per_population', 'Num_HIV/AIDs_Digno', 'Num_AIDS_Digno', 'AIDS_per_population']
# Categorical variables: ['NEIGHBORHOOD', 'SEX', 'RACE/ETHNICITY', 'HIV/AIDS_Among_HIV']

# %%
for k in num_columns:
    plt.figure()
    sns.barplot(x=k , y='NEIGHBORHOOD', data=dataframe)
    plt.gcf().set_size_inches(20, 8)
    plt.plot()

# %% [markdown]
# Finding:
# >1. NEIGHBORHOOD X NUM_HIV_DIAGNO = Bedford Stuyvesant-Crown Heights.
# 2. NEIGHBORHOOD X HIV_per_population = Chelsea-Clinton.
# 3. NEIGHBORHOOD X Num_HIV/AIDs_Digno = Bedford Stuyvesant-Crown Heights.
# 4. NEIGHBORHOOD X HIV/AIDs_Among_HIV = Flushing-Clearview
# 5. NEIGHBORHOOD X Num_AIDS_Digno = Bedford Stuyvesant-Crown Heights.
# 6. NEIGHBORHOOD X AID_per_population = Chelsea-Clinton.

# %%
for k in num_columns:
    plt.figure()
    sns.barplot(x=k , y='SEX', data=dataframe)
    plt.gcf().set_size_inches(30, 8)
    plt.plot()

# %% [markdown]
# Finding:
# > 1. SEX x NUM_HIV_DIAGNO = male
# 2. SEX x HIV_per_population = male
# 3. SEX x Num_HIV/AIDs_Digno = male
# 4. SEX x HIV/AIDs_Among_HIV = male
# 5. SEX x Num_AIDS_Digno = male
# 6. SEX x AID_per_population = male

# %%
for k in num_columns:
    plt.figure()
    sns.barplot(x=k , y='RACE/ETHNICITY', data=dataframe)
    plt.gcf().set_size_inches(30, 8)
    plt.plot()

# %% [markdown]
# Finding:
# > 1. RACE/ETHNICITY x NUM_HIV_DIAGNO = Balck
# 2. RACE/ETHNICITY x HIV_per_population = Black
# 3. RACE/ETHNICITY x Num_HIV/AIDs_Digno = Black
# 4. RACE/ETHNICITY x HIV/AIDs_Among_HIV = Black
# 5. RACE/ETHNICITY x Num_AIDS_Digno = Black
# 6. RACE/ETHNICITY x AID_per_population = Black
#
# Big number of percent race to small number of percent race
# 1. Black
# 2. Hispanic
# 3. White
# 4. Asian/Pacific Islander
# 5. Multiracial

# %% [markdown]
# In this graph, I am checking how people are diagnosed with HIV based on their area and location. We can clearly see that Crown Height has the most number of HIV-infected people and Willowbrook has the least number of HIV-infected people.

# %%
bgr = dataframe.groupby(['NEIGHBORHOOD','Year']).sum()['NUM_HIV_Digno']
bgr.plot(kind="bar", subplots=True, figsize=(30,10))
# Out:
# array([<AxesSubplot:title={'center':'NUM_HIV_Digno'}, xlabel='NEIGHBORHOOD,Year'>],
#       dtype=object)

# %%
bgr = dataframe.groupby(['RACE/ETHNICITY','Year']).sum()['NUM_HIV_Digno']
bgr.plot(kind="bar", subplots=True, color = 'red' , figsize=(30,10))
# Out:
# array([<AxesSubplot:title={'center':'NUM_HIV_Digno'}, xlabel='RACE/ETHNICITY,Year'>],
#       dtype=object)

# %%
plt.subplots(figsize=(100,20))
sns.boxplot(x="NEIGHBORHOOD", y="NUM_HIV_Digno", data=dataframe)
plt.ylim(-1, 100)
plt.ylabel('Total Number of HIV Diagnoses', fontsize=30)
plt.xlabel('Neighborhood', fontsize=1)
# Out:
# Text(0.5, 0, 'Neighborhood')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #Handling missing data

# %%
# create the bar charts to show percents of nonmissing databy missingo function
import missingno as msno 

msno.bar(dataframe)
plt.title(' Percents of non-missing data ',fontsize=20)
# Out:
# Text(0.5, 1.0, ' Percents of non-missing data ')

# %% [markdown]
# As it could be seen there are no missing data , meaning NA

# %% [markdown]
# # Dropping all zero values

# %%
# make a copy to work with
df_copy=dataframe



df_copy=df_copy.where(df_copy!=0)
df_copy=df_copy.dropna()
df_copy

partial=df_copy.shape
overall=dataframe.shape
percentageOfZeroValues=partial[0]/overall[0]
percentageOfZeroValues=percentageOfZeroValues * 100

# %% [markdown]
# 31% of data are either zeros or unkown since we dropped all the NA values in EDA work

# %% [markdown]
# # Scaling the data

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler



scale = StandardScaler()
X = df_copy[['NUM_HIV_Digno',	'HIV_per_population'	,'Num_HIV/AIDs_Digno',	'HIV/AIDS_Among_HIV',	'Num_AIDS_Digno',	'AIDS_per_population']]
scaledX = scale.fit_transform(X)
df = pd.DataFrame(scaledX, columns = ['NUM_HIV_Digno',	'HIV_per_population'	,'Num_HIV/AIDs_Digno',	'HIV/AIDS_Among_HIV',	'Num_AIDS_Digno',	'AIDS_per_population'])

# %% [markdown]
# #Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error


X = df[['NUM_HIV_Digno',	'HIV_per_population'	,'Num_HIV/AIDs_Digno',	'HIV/AIDS_Among_HIV',	'Num_AIDS_Digno']]
y = df['AIDS_per_population']




#25% of the data is set aside to test the model
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = .25)


lm = LinearRegression()
lm.fit(X_train, y_train)

#check the r-square on the data
lm.score(X_train,y_train)
# Out:
# 0.7582226836973843

# %% [markdown]
# #Prediction -Model01

# %%
y_pred = lm.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8485529965699306

# %% [markdown]
# # Decision Tree Regressor-Model2

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
regressorTree = DecisionTreeRegressor(random_state=0)

regressorTree.fit(X_train,y_train)
score = regressorTree.score(X_train, y_train)
print("R-squared:", score) 


ypred2 = regressorTree.predict(X_test)

mse = mean_squared_error(y_test, ypred2)
print("MSE: ", mse)
print("RMSE: ", mse**(1/2.0)) 



x_ax = range(len(y_test))
plt.plot(x_ax, y_test, linewidth=1, label="original")
plt.plot(x_ax, ypred2, linewidth=1.1, label="predicted")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)


plt.gcf().set_size_inches(10, 10)
plt.subplots_adjust(right=2)


plt.grid(True)
plt.show()
# Out:
# R-squared: 1.0
# MSE:  0.36230032041585036
# RMSE:  0.6019138812287439

# %% [markdown]
# A R-squared of 1 indicates that the regression predictions perfectly fit the data.

# %% [markdown]
# # Model3-RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train,y_train) 
Y_predForest = regressor.predict(X_test)
r2_score(y_test,Y_predForest)
# Out:
# 0.7073423890731682

# %% [markdown]
# # Model4-XGBoost Regressor

# %%
from xgboost.sklearn import XGBRegressor

xgb_model = XGBRegressor(objective="reg:linear", random_state=42)
xgb_model.fit(X_train,y_train)
y_pred_XGB = xgb_model.predict(X_test)
r2_score(y_test,y_pred_XGB)

# %% [markdown]
# ##Stacking ensemble of models:
#
# will evaluate the following five algorithms:
#
# Logistic Regression. k-Nearest Neighbors. Decision Tree. Support Vector Machine. Naive Bayes.

# %%
# compare ensemble to each baseline classifier
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import StackingClassifier
from matplotlib import pyplot
 
# get the dataset
def get_dataset():
	X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
	return X, y
 
# get a stacking ensemble of models
def get_stacking():
	# define the base models
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('knn', KNeighborsClassifier()))
	level0.append(('cart', DecisionTreeClassifier()))
	level0.append(('svm', SVC()))
	level0.append(('bayes', GaussianNB()))
	# define meta learner model
	level1 = LogisticRegression()
	# define the stacking ensemble
	model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
	return model
 
# get a list of models to evaluate
#We can include the stacking ensemble in the list of models to evaluate, along with the standalone models.
def get_models():
	models = dict()
	models['lr'] = LogisticRegression()
	models['knn'] = KNeighborsClassifier()
	models['cart'] = DecisionTreeClassifier()
	models['svm'] = SVC()
	models['bayes'] = GaussianNB()
	models['stacking'] = get_stacking()
	return models
 
# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
	return scores
 
# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	scores = evaluate_model(model, X, y)
	results.append(scores)
	names.append(name)
	print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >lr 0.866 (0.029)
# >knn 0.931 (0.025)
# >cart 0.823 (0.038)
# >svm 0.957 (0.020)
# >bayes 0.833 (0.031)
# >stacking 0.965 (0.019)

# %% [markdown]
# he complete example of evaluating the stacking ensemble model alongside the standalone models is listed below.

# %%
# make a prediction with a stacking ensemble
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# define the base models
level0 = list()
level0.append(('lr', LogisticRegression()))
level0.append(('knn', KNeighborsClassifier()))
level0.append(('cart', DecisionTreeClassifier()))
level0.append(('svm', SVC()))
level0.append(('bayes', GaussianNB()))
# define meta learner model
level1 = LogisticRegression()
# define the stacking ensemble
model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(X, y)
# make a prediction for one example
data = [[2.47475454,0.40165523,1.68081787,2.88940715,0.91704519,-3.07950644,4.39961206,0.72464273,-4.86563631,-6.06338084,-1.22209949,-0.4699618,1.01222748,-0.6899355,-0.53000581,6.86966784,-3.27211075,-6.59044146,-2.21290585,-3.139579]]
yhat = model.predict(data)
print('Predicted Class: %d' % (yhat))
# Out:
# Predicted Class: 0

# %% [markdown]
# ##Stacking ensemble of models:
#
# will evaluate the following five algorithms:
#
# Logistic Regression. k-Nearest Neighbors. Decision Tree. Support Vector Machine. Naive Bayes.

# %%
# compare ensemble to each baseline classifier
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import StackingClassifier
from matplotlib import pyplot
 
# get the dataset
def get_dataset():
	X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
	return X, y
 
# get a stacking ensemble of models
def get_stacking():
	# define the base models
	level0 = list()
	level0.append(('lr', LogisticRegression()))
	level0.append(('knn', KNeighborsClassifier()))
	level0.append(('cart', DecisionTreeClassifier()))
	level0.append(('svm', SVC()))
	level0.append(('bayes', GaussianNB()))
	# define meta learner model
	level1 = LogisticRegression()
	# define the stacking ensemble
	model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
	return model
 
# get a list of models to evaluate
#We can include the stacking ensemble in the list of models to evaluate, along with the standalone models.
def get_models():
	models = dict()
	models['lr'] = LogisticRegression()
	models['knn'] = KNeighborsClassifier()
	models['cart'] = DecisionTreeClassifier()
	models['svm'] = SVC()
	models['bayes'] = GaussianNB()
	models['stacking'] = get_stacking()
	return models
 
# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
	return scores
 
# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	scores = evaluate_model(model, X, y)
	results.append(scores)
	names.append(name)
	print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >lr 0.866 (0.029)
# >knn 0.931 (0.025)
# >cart 0.817 (0.043)
# >svm 0.957 (0.020)
# >bayes 0.833 (0.031)
# >stacking 0.965 (0.019)

# %% [markdown]
# The complete example of evaluating the stacking ensemble model alongside the standalone models is listed below.

# %%
# make a prediction with a stacking ensemble
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# define the base models
level0 = list()
level0.append(('lr', LogisticRegression()))
level0.append(('knn', KNeighborsClassifier()))
level0.append(('cart', DecisionTreeClassifier()))
level0.append(('svm', SVC()))
level0.append(('bayes', GaussianNB()))
# define meta learner model
level1 = LogisticRegression()
# define the stacking ensemble
model = StackingClassifier(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(X, y)
# make a prediction for one example
data = [[2.47475454,0.40165523,1.68081787,2.88940715,0.91704519,-3.07950644,4.39961206,0.72464273,-4.86563631,-6.06338084,-1.22209949,-0.4699618,1.01222748,-0.6899355,-0.53000581,6.86966784,-3.27211075,-6.59044146,-2.21290585,-3.139579]]
yhat = model.predict(data)
print('Predicted Class: %d' % (yhat))
# Out:
# Predicted Class: 0

# %% [markdown]
# ### Stacking for Regression

# %%
# compare machine learning models for regression
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from matplotlib import pyplot
 
# get the dataset
def get_dataset():
	X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=1)
	return X, y
 
# get a list of models to evaluate
def get_models():
	models = dict()
	models['knn'] = KNeighborsRegressor()
	models['cart'] = DecisionTreeRegressor()
	models['svm'] = SVR()
	return models
 
# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
	return scores
 
# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	scores = evaluate_model(model, X, y)
	results.append(scores)
	names.append(name)
	print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >knn -101.019 (7.161)
# >cart -148.293 (11.415)
# >svm -162.419 (12.565)

# %% [markdown]
# KNN performs the best with a mean negative MAE of about -101.019

# %%
# make a prediction with a stacking ensemble
from sklearn.ensemble import StackingRegressor
# define dataset
X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=1)
# define the base models
level0 = list()
level0.append(('knn', KNeighborsRegressor()))
level0.append(('cart', DecisionTreeRegressor()))
level0.append(('svm', SVR()))
# define meta learner model
level1 = LinearRegression()
# define the stacking ensemble
model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(X, y)
# make a prediction for one example
data = [[0.59332206,-0.56637507,1.34808718,-0.57054047,-0.72480487,1.05648449,0.77744852,0.07361796,0.88398267,2.02843157,1.01902732,0.11227799,0.94218853,0.26741783,0.91458143,-0.72759572,1.08842814,-0.61450942,-0.69387293,1.69169009]]
yhat = model.predict(data)
print('Predicted Value: %.3f' % (yhat))
# Out:
# Predicted Value: 556.914

# %% [markdown]
# # Conclusion
# In the beginning, when we loaded the data, most of the data were being read as an object so we had to convert our numerical data to float so we can process the data and look at the correlations and explore the data to get insights. We made bivariate and univariate graphs to extract more information through visualization. Also, there was another challenge before the data could be processed for exploration. There was data cleaning early in the EDA since all the columns contained special characters which were avoiding us to cast the columns to float values. So, we had to remove all those special characters. To conclude, when we compare males vs females, males are at a higher risk of being exposed to HIV. Also, our finding shows black and Hispanic men are at the greatest risk of being exposed to HIV.  In regard to modeling the data, we used XGBoost Regressor, RandomForestRegressor, Linear Regression, and Tree Regressor to model the dataset. By comparing they accuracy of the 4 generated models, we can say that linear regression and tree regression are more accurate of all models we generated. Our preferred model would be linear regression with an accuracy of 83%.

# %% [markdown]
# [FinalProject.pdf](https://drive.google.com/open?id=1ZkaTvJzXDaOZa4oxqdtKEdzlyKxyuGzw)
